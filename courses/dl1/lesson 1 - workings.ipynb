# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# This file contains all the main external libs we'll use
from fastai.imports import *

from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "test-data/"
sz = 224

# %% [markdown]
# Does our directory structure look ok?

# %%
os.listdir(PATH)
# Out:
# ['valid', 'train']

# %%
os.listdir(f'{PATH}valid')
# Out:
# ['hockey', 'afl']

# %% [markdown]
# Is there a footy image there?

# %%
files = os.listdir(f'{PATH}valid/afl')[:4]
files
# Out:
# ['9. gettyimages-611838498.jpg',
#  '53. muprhy-riewoldt_8hkkj4d1njmk1fx0kd0ajqs39.jpg',
#  '1. 8669256-3x2-700x467.jpg',
#  '50. turf_afl-2018.jpg']

# %%
img = plt.imread(f'{PATH}valid/afl/{files[3]}')
plt.imshow(img)

# %%
img.shape
# Out:
# (473, 710, 3)

# %%
arch = resnet34
tfms = tfms_from_model(arch, sz)
data = ImageClassifierData.from_paths(PATH, tfms=tfms)
learn = ConvLearner.pretrained(arch, data, precompute=True)

# %% [markdown]
# Determine a reasonable learning rate

# %%
lrf = learn.lr_find()

# %% [markdown]
# Where does our loss stop decreasing

# %%
learn.sched.plot()

# %% [markdown]
# Ok, lets use x
